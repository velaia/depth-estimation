# %% [markdown]
# # Depth Estimation using NYU Depth V2 dataset

# %% [markdown]
# I use an approach of programming called [exploratory programming](https://en.wikipedia.org/wiki/Exploratory_programming) here. Jupyter is a common tool in the data science / AI world, widely used and perfectly suited for this approach.

# %% [markdown]
# ## Tasks

# %% [markdown]
# * Model + training & eval script on NYU Depth V2 - arch as tiny as possible (as long as it does the job)
# * Demonstrate use of different opts, cbs esp. lr schedulers

# %% [markdown]
# ## Acquire & explore dataset + prepare

# %% [markdown]
# ### kaggle approach (deprecated)

# %%
# !kaggle datasets download soumikrakshit/nyu-depth-v2
# Out:
# nyu-depth-v2.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip -q nyu-depth-v2.zip -d data

# %%
# !ls data/nyu_data/data
# Out:
# nyu2_test      nyu2_test.csv  nyu2_train     nyu2_train.csv

# %%
# !du -h -d 3 data
# Out:
# 3.9G	data/nyu_data/data/nyu2_train
# 419M	data/nyu_data/data/nyu2_test
# 4.3G	data/nyu_data/data
# 4.3G	data/nyu_data
# 4.3G	data

# %%
# !ls data/nyu_data/data/nyu2_test
# Out:
# 00000_colors.png 00412_depth.png  00769_colors.png 01148_depth.png
# 00000_depth.png  00413_colors.png 00769_depth.png  01149_colors.png
# 00001_colors.png 00413_depth.png  00770_colors.png 01149_depth.png
# 00001_depth.png  00429_colors.png 00770_depth.png  01150_colors.png
# 00008_colors.png 00429_depth.png  00771_colors.png 01150_depth.png
# 00008_depth.png  00430_colors.png 00771_depth.png  01151_colors.png
# 00013_colors.png 00430_depth.png  00772_colors.png 01151_depth.png
# 00013_depth.png  00431_colors.png 00772_depth.png  01152_colors.png
# 00014_colors.png 00431_depth.png  00773_colors.png 01152_depth.png
# 00014_depth.png  00432_colors.png 00773_depth.png  01153_colors.png
# 00015_colors.png 00432_depth.png  00774_colors.png 01153_depth.png
# 00015_depth.png  00433_colors.png 00774_depth.png  01154_colors.png
# 00016_colors.png 00433_depth.png  00775_colors.png 01154_depth.png
# 00016_depth.png  00434_colors.png 00775_depth.png  01155_colors.png
# 00017_colors.png 00434_depth.png  00776_colors.png 01155_depth.png
# 00017_depth.png  00440_colors.png 00776_depth.png  01156_colors.png
# 00020_colors.png 00440_depth.png  00777_colors.png 01156_depth.png
# 00020_depth.png  00441_colors.png 00777_depth.png  01157_colors.png
# 00027_colors.png 00441_depth.png  00778_colors.png 01157_depth.png
# 00027_depth.png  00442_colors.png 00778_depth.png  01161_colors.png
# 00028_colors.png 00442_depth.png  00779_colors.png 01161_depth.png
# 00028_depth.png  00443_colors.png 00779_depth.png  01162_colors.png
# 00029_colors.png 00443_depth.png  00780_colors.png 01162_depth.png
# 00029_depth.png  00444_colors.png 00780_depth.png  01163_colors.png
# 00030_colors.png 00444_depth.png  00781_colors.png 01163_depth.png
# 00030_depth.png  00445_colors.png 00781_depth.png  01164_colors.png
# 00031_colors.png 00445_depth.png  00782_colors.png 01164_depth.png
# 00031_depth.png  00446_colors.png 00782_depth.png  01165_colors.png
# 00032_colors.png 00446_depth.png  00783_colors.png 01165_depth.png
# 00032_depth.png  00447_colors.png 00783_depth.png  01166_colors.png
# 00033_colors.png 00447_depth.png  00784_colors.png 01166_depth.png
# 00033_depth.png  00461_colors.png 00784_depth.png  01169_colors.png
# 00034_colors.png 00461_depth.png  00785_colors.png 01169_depth.png
# 00034_depth.png  00462_colors.png 00785_depth.png  01170_colors.png
# 00035_colors.png 00462_depth.png  00786_colors.png 01170_depth.png
# 00035_depth.png  00463_colors.png 00786_depth.png  01173_colors.png
# 00036_colors.png 00463_depth.png  00799_colors.png 01173_depth.png
# 00036_depth.png  00464_colors.png 00799_depth.png  01174_colors.png
# 00037_colors.png 00464_depth.png  00800_colors.png 01174_depth.png
# 00037_depth.png  00465_colors.png 00800_depth.png  01175_colors.png
# 00038_colors.png 00465_depth.png  00801_colors.png 01175_depth.png
# 00038_depth.png  00468_colors.png 00801_depth.png  01178_colors.png
# 00039_colors.png 00468_depth.png  00802_colors.png 01178_depth.png
# 00039_depth.png  00469_colors.png 00802_depth.png  01179_colors.png
# 00040_colors.png 00469_depth.png  00803_colors.png 01179_depth.png
# 00040_depth.png  00470_colors.png 00803_depth.png  01180_colors.png
# 00041_colors.png 00470_depth.png  00809_colors.png 01180_depth.png
# 00041_depth.png  00471_colors.png 00809_depth.png  01181_colors.png
# 00042_colors.png 00471_depth.png  00810_colors.png 01181_depth.png
# 00042_depth.png  00472_colors.png 00810_depth.png  01182_colors.png
# 00045_colors.png 00472_depth.png  00811_colors.png 01182_depth.png
# 00045_depth.png  00473_colors.png 00811_depth.png  01183_colors.png
# 00046_colors.png 00473_depth.png  00812_colors.png 01183_depth.png
# 00046_depth.png  00474_colors.png 00812_depth.png  01191_colors.png
# 00055_colors.png 00474_depth.png  00813_colors.png 01191_depth.png
# 00055_depth.png  00475_colors.png 00813_depth.png  01192_colors.png
# 00056_colors.png 00475_depth.png  00820_colors.png 01192_depth.png
# 00056_depth.png  00476_colors.png 00820_depth.png  01193_colors.png
# 00058_colors.png 00476_depth.png  00821_colors.png 01193_depth.png
# 00058_depth.png  00507_colors.png 00821_depth.png  01194_colors.png
# 00059_colors.png 00507_depth.png  00822_colors.png 01194_depth.png
# 00059_depth.png  00508_colors.png 00822_depth.png  01195_colors.png
# 00060_colors.png 00508_depth.png  00832_colors.png 01195_depth.png
# 00060_depth.png  00509_colors.png 00832_depth.png  01200_colors.png
# 00061_colors.png 00509_depth.png  00833_colors.png 01200_depth.png
# 00061_depth.png  00510_colors.png 00833_depth.png  01201_colors.png
# 00062_colors.png 00510_depth.png  00834_colors.png 01201_depth.png
# 00062_depth.png  00511_colors.png 00834_depth.png  01202_colors.png
# 00075_colors.png 00511_depth.png  00835_colors.png 01202_depth.png
# 00075_depth.png  00512_colors.png 00835_depth.png  01203_colors.png
# 00076_colors.png 00512_depth.png  00836_colors.png 01203_depth.png
# 00076_depth.png  00514_colors.png 00836_depth.png  01204_colors.png
# 00077_colors.png 00514_depth.png  00837_colors.png 01204_depth.png
# 00077_depth.png  00515_colors.png 00837_depth.png  01205_colors.png
# 00078_colors.png 00515_depth.png  00838_colors.png 01205_depth.png
# 00078_depth.png  00516_colors.png 00838_depth.png  01206_colors.png
# 00083_colors.png 00516_depth.png  00839_colors.png 01206_depth.png
# 00083_depth.png  00517_colors.png 00839_depth.png  01207_colors.png
# 00084_colors.png 00517_depth.png  00840_colors.png 01207_depth.png
# 00084_depth.png  00518_colors.png 00840_depth.png  01208_colors.png
# 00085_colors.png 00518_depth.png  00841_colors.png 01208_depth.png
# 00085_depth.png  00519_colors.png 00841_depth.png  01209_colors.png
# 00086_colors.png 00519_depth.png  00842_colors.png 01209_depth.png
# 00086_depth.png  00520_colors.png 00842_depth.png  01210_colors.png
# 00087_colors.png 00520_depth.png  00843_colors.png 01210_depth.png
# 00087_depth.png  00521_colors.png 00843_depth.png  01211_colors.png
# 00088_colors.png 00521_depth.png  00844_colors.png 01211_depth.png
# 00088_depth.png  00522_colors.png 00844_depth.png  01215_colors.png
# 00089_colors.png 00522_depth.png  00845_colors.png 01215_depth.png
# 00089_depth.png  00523_colors.png 00845_depth.png  01216_colors.png
# 00090_colors.png 00523_depth.png  00849_colors.png 01216_depth.png
# 00090_depth.png  00524_colors.png 00849_depth.png  01217_colors.png
# 00116_colors.png 00524_depth.png  00850_colors.png 01217_depth.png
# 00116_depth.png  00525_colors.png 00850_depth.png  01218_colors.png
# 00117_colors.png 00525_depth.png  00851_colors.png 01218_depth.png
# 00117_depth.png  00530_colors.png 00851_depth.png  01219_colors.png
# 00118_colors.png 00530_depth.png  00856_colors.png 01219_depth.png
# 00118_depth.png  00531_colors.png 00856_depth.png  01225_colors.png
# 00124_colors.png 00531_depth.png  00857_colors.png 01225_depth.png
# 00124_depth.png  00532_colors.png 00857_depth.png  01226_colors.png
# 00125_colors.png 00532_depth.png  00858_colors.png 01226_depth.png
# 00125_depth.png  00536_colors.png 00858_depth.png  01227_colors.png
# 00126_colors.png 00536_depth.png  00859_colors.png 01227_depth.png
# 00126_depth.png  00537_colors.png 00859_depth.png  01228_colors.png
# 00127_colors.png 00537_depth.png  00860_colors.png 01228_depth.png
# 00127_depth.png  00538_colors.png 00860_depth.png  01229_colors.png
# 00128_colors.png 00538_depth.png  00861_colors.png 01229_depth.png
# 00128_depth.png  00548_colors.png 00861_depth.png  01232_colors.png
# 00130_colors.png 00548_depth.png  00868_colors.png 01232_depth.png
# 00130_depth.png  00549_colors.png 00868_depth.png  01233_colors.png
# 00131_colors.png 00549_depth.png  00869_colors.png 01233_depth.png
# 00131_depth.png  00550_colors.png 00869_depth.png  01234_colors.png
# 00132_colors.png 00550_depth.png  00870_colors.png 01234_depth.png
# 00132_depth.png  00554_colors.png 00870_depth.png  01246_colors.png
# 00133_colors.png 00554_depth.png  00905_colors.png 01246_depth.png
# 00133_depth.png  00555_colors.png 00905_depth.png  01247_colors.png
# 00136_colors.png 00555_depth.png  00906_colors.png 01247_depth.png
# 00136_depth.png  00556_colors.png 00906_depth.png  01248_colors.png
# 00152_colors.png 00556_depth.png  00907_colors.png 01248_depth.png
# 00152_depth.png  00557_colors.png 00907_depth.png  01249_colors.png
# 00153_colors.png 00557_depth.png  00916_colors.png 01249_depth.png
# 00153_depth.png  00558_colors.png 00916_depth.png  01253_colors.png
# 00154_colors.png 00558_depth.png  00917_colors.png 01253_depth.png
# 00154_depth.png  00559_colors.png 00917_depth.png  01254_colors.png
# 00166_colors.png 00559_depth.png  00918_colors.png 01254_depth.png
# 00166_depth.png  00560_colors.png 00918_depth.png  01255_colors.png
# 00167_colors.png 00560_depth.png  00925_colors.png 01255_depth.png
# 00167_depth.png  00561_colors.png 00925_depth.png  01256_colors.png
# 00168_colors.png 00561_depth.png  00926_colors.png 01256_depth.png
# 00168_depth.png  00562_colors.png 00926_depth.png  01257_colors.png
# 00170_colors.png 00562_depth.png  00927_colors.png 01257_depth.png
# 00170_depth.png  00563_colors.png 00927_depth.png  01258_colors.png
# 00171_colors.png 00563_depth.png  00931_colors.png 01258_depth.png
# 00171_depth.png  00564_colors.png 00931_depth.png  01259_colors.png
# 00172_colors.png 00564_depth.png  00932_colors.png 01259_depth.png
# 00172_depth.png  00565_colors.png 00932_depth.png  01260_colors.png
# 00173_colors.png 00565_depth.png  00933_colors.png 01260_depth.png
# 00173_depth.png  00566_colors.png 00933_depth.png  01261_colors.png
# 00174_colors.png 00566_depth.png  00934_colors.png 01261_depth.png
# 00174_depth.png  00567_colors.png 00934_depth.png  01262_colors.png
# 00175_colors.png 00567_depth.png  00944_colors.png 01262_depth.png
# 00175_depth.png  00568_colors.png 00944_depth.png  01263_colors.png
# 00179_colors.png 00568_depth.png  00945_colors.png 01263_depth.png
# 00179_depth.png  00569_colors.png 00945_depth.png  01264_colors.png
# 00180_colors.png 00569_depth.png  00946_colors.png 01264_depth.png
# 00180_depth.png  00570_colors.png 00946_depth.png  01274_colors.png
# 00181_colors.png 00570_depth.png  00958_colors.png 01274_depth.png
# 00181_depth.png  00578_colors.png 00958_depth.png  01275_colors.png
# 00182_colors.png 00578_depth.png  00959_colors.png 01275_depth.png
# 00182_depth.png  00579_colors.png 00959_depth.png  01276_colors.png
# 00183_colors.png 00579_depth.png  00960_colors.png 01276_depth.png
# 00183_depth.png  00580_colors.png 00960_depth.png  01277_colors.png
# 00184_colors.png 00580_depth.png  00961_colors.png 01277_depth.png
# 00184_depth.png  00581_colors.png 00961_depth.png  01278_colors.png
# 00185_colors.png 00581_depth.png  00964_colors.png 01278_depth.png
# 00185_depth.png  00582_colors.png 00964_depth.png  01279_colors.png
# 00186_colors.png 00582_depth.png  00965_colors.png 01279_depth.png
# 00186_depth.png  00590_colors.png 00965_depth.png  01284_colors.png
# 00187_colors.png 00590_depth.png  00966_colors.png 01284_depth.png
# 00187_depth.png  00591_colors.png 00966_depth.png  01285_colors.png
# 00188_colors.png 00591_depth.png  00969_colors.png 01285_depth.png
# 00188_depth.png  00592_colors.png 00969_depth.png  01286_colors.png
# 00189_colors.png 00592_depth.png  00970_colors.png 01286_depth.png
# 00189_depth.png  00593_colors.png 00970_depth.png  01287_colors.png
# 00190_colors.png 00593_depth.png  00971_colors.png 01287_depth.png
# 00190_depth.png  00602_colors.png 00971_depth.png  01288_colors.png
# 00191_colors.png 00602_depth.png  00972_colors.png 01288_depth.png
# 00191_depth.png  00603_colors.png 00972_depth.png  01289_colors.png
# 00192_colors.png 00603_depth.png  00973_colors.png 01289_depth.png
# 00192_depth.png  00604_colors.png 00973_depth.png  01290_colors.png
# 00193_colors.png 00604_depth.png  00974_colors.png 01290_depth.png
# 00193_depth.png  00605_colors.png 00974_depth.png  01291_colors.png
# 00194_colors.png 00605_depth.png  00975_colors.png 01291_depth.png
# 00194_depth.png  00606_colors.png 00975_depth.png  01292_colors.png
# 00195_colors.png 00606_depth.png  00976_colors.png 01292_depth.png
# 00195_depth.png  00611_colors.png 00976_depth.png  01293_colors.png
# 00196_colors.png 00611_depth.png  00990_colors.png 01293_depth.png
# 00196_depth.png  00612_colors.png 00990_depth.png  01294_colors.png
# 00197_colors.png 00612_depth.png  00991_colors.png 01294_depth.png
# 00197_depth.png  00616_colors.png 00991_depth.png  01296_colors.png
# 00198_colors.png 00616_depth.png  00992_colors.png 01296_depth.png
# 00198_depth.png  00617_colors.png 00992_depth.png  01297_colors.png
# 00199_colors.png 00617_depth.png  00993_colors.png 01297_depth.png
# 00199_depth.png  00618_colors.png 00993_depth.png  01298_colors.png
# 00200_colors.png 00618_depth.png  00994_colors.png 01298_depth.png
# 00200_depth.png  00619_colors.png 00994_depth.png  01301_colors.png
# 00201_colors.png 00619_depth.png  01000_colors.png 01301_depth.png
# 00201_depth.png  00620_colors.png 01000_depth.png  01302_colors.png
# 00206_colors.png 00620_depth.png  01001_colors.png 01302_depth.png
# 00206_depth.png  00632_colors.png 01001_depth.png  01303_colors.png
# 00207_colors.png 00632_depth.png  01002_colors.png 01303_depth.png
# 00207_depth.png  00633_colors.png 01002_depth.png  01304_colors.png
# 00208_colors.png 00633_depth.png  01003_colors.png 01304_depth.png
# 00208_depth.png  00634_colors.png 01003_depth.png  01305_colors.png
# 00209_colors.png 00634_depth.png  01009_colors.png 01305_depth.png
# 00209_depth.png  00635_colors.png 01009_depth.png  01306_colors.png
# 00210_colors.png 00635_depth.png  01010_colors.png 01306_depth.png
# 00210_depth.png  00636_colors.png 01010_depth.png  01307_colors.png
# 00211_colors.png 00636_depth.png  01011_colors.png 01307_depth.png
# 00211_depth.png  00637_colors.png 01011_depth.png  01313_colors.png
# 00219_colors.png 00637_depth.png  01020_colors.png 01313_depth.png
# 00219_depth.png  00643_colors.png 01020_depth.png  01314_colors.png
# 00220_colors.png 00643_depth.png  01021_colors.png 01314_depth.png
# 00220_depth.png  00644_colors.png 01021_depth.png  01328_colors.png
# 00221_colors.png 00644_depth.png  01022_colors.png 01328_depth.png
# 00221_depth.png  00649_colors.png 01022_depth.png  01329_colors.png
# 00249_colors.png 00649_depth.png  01031_colors.png 01329_depth.png
# 00249_depth.png  00650_colors.png 01031_depth.png  01330_colors.png
# 00263_colors.png 00650_depth.png  01032_colors.png 01330_depth.png
# 00263_depth.png  00655_colors.png 01032_depth.png  01331_colors.png
# 00270_colors.png 00655_depth.png  01033_colors.png 01331_depth.png
# 00270_depth.png  00656_colors.png 01033_depth.png  01334_colors.png
# 00271_colors.png 00656_depth.png  01037_colors.png 01334_depth.png
# 00271_depth.png  00657_colors.png 01037_depth.png  01335_colors.png
# 00272_colors.png 00657_depth.png  01038_colors.png 01335_depth.png
# 00272_depth.png  00662_colors.png 01038_depth.png  01336_colors.png
# 00278_colors.png 00662_depth.png  01047_colors.png 01336_depth.png
# 00278_depth.png  00663_colors.png 01047_depth.png  01337_colors.png
# 00279_colors.png 00663_depth.png  01048_colors.png 01337_depth.png
# 00279_depth.png  00667_colors.png 01048_depth.png  01338_colors.png
# 00280_colors.png 00667_depth.png  01051_colors.png 01338_depth.png
# 00280_depth.png  00668_colors.png 01051_depth.png  01339_colors.png
# 00281_colors.png 00668_depth.png  01052_colors.png 01339_depth.png
# 00281_depth.png  00669_colors.png 01052_depth.png  01346_colors.png
# 00282_colors.png 00669_depth.png  01056_colors.png 01346_depth.png
# 00282_depth.png  00670_colors.png 01056_depth.png  01347_colors.png
# 00283_colors.png 00670_depth.png  01057_colors.png 01347_depth.png
# 00283_depth.png  00671_colors.png 01057_depth.png  01348_colors.png
# 00284_colors.png 00671_depth.png  01074_colors.png 01348_depth.png
# 00284_depth.png  00672_colors.png 01074_depth.png  01352_colors.png
# 00295_colors.png 00672_depth.png  01075_colors.png 01352_depth.png
# 00295_depth.png  00675_colors.png 01075_depth.png  01353_colors.png
# 00296_colors.png 00675_depth.png  01076_colors.png 01353_depth.png
# 00296_depth.png  00676_colors.png 01076_depth.png  01354_colors.png
# 00297_colors.png 00676_depth.png  01077_colors.png 01354_depth.png
# 00297_depth.png  00677_colors.png 01077_depth.png  01355_colors.png
# 00298_colors.png 00677_depth.png  01078_colors.png 01355_depth.png
# 00298_depth.png  00678_colors.png 01078_depth.png  01363_colors.png
# 00299_colors.png 00678_depth.png  01079_colors.png 01363_depth.png
# 00299_depth.png  00679_colors.png 01079_depth.png  01364_colors.png
# 00300_colors.png 00679_depth.png  01080_colors.png 01364_depth.png
# 00300_depth.png  00680_colors.png 01080_depth.png  01367_colors.png
# 00301_colors.png 00680_depth.png  01081_colors.png 01367_depth.png
# 00301_depth.png  00685_colors.png 01081_depth.png  01368_colors.png
# 00309_colors.png 00685_depth.png  01082_colors.png 01368_depth.png
# 00309_depth.png  00686_colors.png 01082_depth.png  01383_colors.png
# 00310_colors.png 00686_depth.png  01083_colors.png 01383_depth.png
# 00310_depth.png  00687_colors.png 01083_depth.png  01384_colors.png
# 00311_colors.png 00687_depth.png  01087_colors.png 01384_depth.png
# 00311_depth.png  00688_colors.png 01087_depth.png  01385_colors.png
# 00314_colors.png 00688_depth.png  01088_colors.png 01385_depth.png
# 00314_depth.png  00689_colors.png 01088_depth.png  01386_colors.png
# 00315_colors.png 00689_depth.png  01089_colors.png 01386_depth.png
# 00315_depth.png  00692_colors.png 01089_depth.png  01387_colors.png
# 00316_colors.png 00692_depth.png  01090_colors.png 01387_depth.png
# 00316_depth.png  00693_colors.png 01090_depth.png  01388_colors.png
# 00324_colors.png 00693_depth.png  01091_colors.png 01388_depth.png
# 00324_depth.png  00696_colors.png 01091_depth.png  01389_colors.png
# 00325_colors.png 00696_depth.png  01092_colors.png 01389_depth.png
# 00325_depth.png  00697_colors.png 01092_depth.png  01390_colors.png
# 00326_colors.png 00697_depth.png  01093_colors.png 01390_depth.png
# 00326_depth.png  00698_colors.png 01093_depth.png  01393_colors.png
# 00327_colors.png 00698_depth.png  01094_colors.png 01393_depth.png
# 00327_depth.png  00705_colors.png 01094_depth.png  01394_colors.png
# 00328_colors.png 00705_depth.png  01095_colors.png 01394_depth.png
# 00328_depth.png  00706_colors.png 01095_depth.png  01395_colors.png
# 00329_colors.png 00706_depth.png  01097_colors.png 01395_depth.png
# 00329_depth.png  00707_colors.png 01097_depth.png  01396_colors.png
# 00330_colors.png 00707_depth.png  01098_colors.png 01396_depth.png
# 00330_depth.png  00708_colors.png 01098_depth.png  01397_colors.png
# 00331_colors.png 00708_depth.png  01099_colors.png 01397_depth.png
# 00331_depth.png  00709_colors.png 01099_depth.png  01398_colors.png
# 00332_colors.png 00709_depth.png  01100_colors.png 01398_depth.png
# 00332_depth.png  00710_colors.png 01100_depth.png  01399_colors.png
# 00333_colors.png 00710_depth.png  01101_colors.png 01399_depth.png
# 00333_depth.png  00711_colors.png 01101_depth.png  01400_colors.png
# 00334_colors.png 00711_depth.png  01102_colors.png 01400_depth.png
# 00334_depth.png  00712_colors.png 01102_depth.png  01406_colors.png
# 00350_colors.png 00712_depth.png  01103_colors.png 01406_depth.png
# 00350_depth.png  00716_colors.png 01103_depth.png  01407_colors.png
# 00351_colors.png 00716_depth.png  01105_colors.png 01407_depth.png
# 00351_depth.png  00717_colors.png 01105_depth.png  01408_colors.png
# 00354_colors.png 00717_depth.png  01106_colors.png 01408_depth.png
# 00354_depth.png  00723_colors.png 01106_depth.png  01409_colors.png
# 00355_colors.png 00723_depth.png  01107_colors.png 01409_depth.png
# 00355_depth.png  00724_colors.png 01107_depth.png  01410_colors.png
# 00356_colors.png 00724_depth.png  01108_colors.png 01410_depth.png
# 00356_depth.png  00725_colors.png 01108_depth.png  01411_colors.png
# 00357_colors.png 00725_depth.png  01116_colors.png 01411_depth.png
# 00357_depth.png  00726_colors.png 01116_depth.png  01412_colors.png
# 00358_colors.png 00726_depth.png  01117_colors.png 01412_depth.png
# 00358_depth.png  00727_colors.png 01117_depth.png  01413_colors.png
# 00359_colors.png 00727_depth.png  01118_colors.png 01413_depth.png
# 00359_depth.png  00730_colors.png 01118_depth.png  01420_colors.png
# 00360_colors.png 00730_depth.png  01122_colors.png 01420_depth.png
# 00360_depth.png  00731_colors.png 01122_depth.png  01421_colors.png
# 00361_colors.png 00731_depth.png  01123_colors.png 01421_depth.png
# 00361_depth.png  00732_colors.png 01123_depth.png  01422_colors.png
# 00362_colors.png 00732_depth.png  01124_colors.png 01422_depth.png
# 00362_depth.png  00733_colors.png 01124_depth.png  01423_colors.png
# 00363_colors.png 00733_depth.png  01125_colors.png 01423_depth.png
# 00363_depth.png  00742_colors.png 01125_depth.png  01429_colors.png
# 00383_colors.png 00742_depth.png  01126_colors.png 01429_depth.png
# 00383_depth.png  00743_colors.png 01126_depth.png  01430_colors.png
# 00384_colors.png 00743_depth.png  01127_colors.png 01430_depth.png
# 00384_depth.png  00758_colors.png 01127_depth.png  01431_colors.png
# 00385_colors.png 00758_depth.png  01128_colors.png 01431_depth.png
# 00385_depth.png  00759_colors.png 01128_depth.png  01432_colors.png
# 00386_colors.png 00759_depth.png  01129_colors.png 01432_depth.png
# 00386_depth.png  00760_colors.png 01129_depth.png  01440_colors.png
# 00387_colors.png 00760_depth.png  01130_colors.png 01440_depth.png
# 00387_depth.png  00761_colors.png 01130_depth.png  01441_colors.png
# 00388_colors.png 00761_depth.png  01134_colors.png 01441_depth.png
# 00388_depth.png  00762_colors.png 01134_depth.png  01442_colors.png
# 00389_colors.png 00762_depth.png  01135_colors.png 01442_depth.png
# 00389_depth.png  00763_colors.png 01135_depth.png  01443_colors.png
# 00394_colors.png 00763_depth.png  01143_colors.png 01443_depth.png
# 00394_depth.png  00764_colors.png 01143_depth.png  01444_colors.png
# 00395_colors.png 00764_depth.png  01144_colors.png 01444_depth.png
# 00395_depth.png  00765_colors.png 01144_depth.png  01445_colors.png
# 00396_colors.png 00765_depth.png  01145_colors.png 01445_depth.png
# 00396_depth.png  00766_colors.png 01145_depth.png  01446_colors.png
# 00410_colors.png 00766_depth.png  01146_colors.png 01446_depth.png
# 00410_depth.png  00767_colors.png 01146_depth.png  01447_colors.png
# 00411_colors.png 00767_depth.png  01147_colors.png 01447_depth.png
# 00411_depth.png  00768_colors.png 01147_depth.png  01448_colors.png
# 00412_colors.png 00768_depth.png  01148_colors.png 01448_depth.png

# %%
# !ls data/nyu_data/data/nyu2_train
# Out:
# basement_0001a_out        bedroom_0116_out          kitchen_0035a_out
# basement_0001b_out        bedroom_0118_out          kitchen_0035b_out
# bathroom_0001_out         bedroom_0120_out          kitchen_0037_out
# bathroom_0002_out         bedroom_0124_out          kitchen_0041_out
# bathroom_0005_out         bedroom_0125a_out         kitchen_0043_out
# bathroom_0006_out         bedroom_0125b_out         kitchen_0045a_out
# bathroom_0007_out         bedroom_0126_out          kitchen_0045b_out
# bathroom_0010_out         bedroom_0129_out          kitchen_0047_out
# bathroom_0011_out         bedroom_0130_out          kitchen_0048_out
# bathroom_0013_out         bedroom_0132_out          kitchen_0049_out
# bathroom_0014a_out        bedroom_0136_out          kitchen_0050_out
# bathroom_0016_out         bedroom_0138_out          kitchen_0051_out
# bathroom_0019_out         bedroom_0140_out          kitchen_0052_out
# bathroom_0023_out         bookstore_0001d_out       kitchen_0053_out
# bathroom_0024_out         bookstore_0001e_out       kitchen_0059_out
# bathroom_0028_out         bookstore_0001f_out       kitchen_0060_out
# bathroom_0030_out         bookstore_0001g_out       laundry_room_0001_out
# bathroom_0033_out         bookstore_0001h_out       living_room_0004_out
# bathroom_0034_out         bookstore_0001i_out       living_room_0005_out
# bathroom_0035_out         bookstore_0001j_out       living_room_0006_out
# bathroom_0039_out         cafe_0001a_out            living_room_0010_out
# bathroom_0041_out         cafe_0001b_out            living_room_0011_out
# bathroom_0042_out         cafe_0001c_out            living_room_0012_out
# bathroom_0045a_out        classroom_0003_out        living_room_0018_out
# bathroom_0048_out         classroom_0004_out        living_room_0019_out
# bathroom_0049_out         classroom_0005_out        living_room_0020_out
# bathroom_0050_out         classroom_0006_out        living_room_0022_out
# bathroom_0051_out         classroom_0010_out        living_room_0029_out
# bathroom_0053_out         classroom_0011_out        living_room_0032_out
# bathroom_0054_out         classroom_0012_out        living_room_0033_out
# bathroom_0055_out         classroom_0016_out        living_room_0035_out
# bathroom_0056_out         classroom_0018_out        living_room_0037_out
# bathroom_0057_out         classroom_0022_out        living_room_0038_out
# bedroom_0004_out          computer_lab_0002_out     living_room_0039_out
# bedroom_0010_out          conference_room_0001_out  living_room_0040_out
# bedroom_0012_out          conference_room_0002_out  living_room_0042a_out
# bedroom_0014_out          dinette_0001_out          living_room_0042b_out
# bedroom_0015_out          dining_room_0001b_out     living_room_0046a_out
# bedroom_0016_out          dining_room_0002_out      living_room_0046b_out
# bedroom_0017_out          dining_room_0004_out      living_room_0047a_out
# bedroom_0019_out          dining_room_0007_out      living_room_0047b_out
# bedroom_0020_out          dining_room_0008_out      living_room_0050_out
# bedroom_0021_out          dining_room_0010_out      living_room_0055_out
# bedroom_0025_out          dining_room_0012_out      living_room_0058_out
# bedroom_0026_out          dining_room_0013_out      living_room_0062_out
# bedroom_0028_out          dining_room_0014_out      living_room_0063_out
# bedroom_0029_out          dining_room_0015_out      living_room_0067_out
# bedroom_0031_out          dining_room_0016_out      living_room_0068_out
# bedroom_0033_out          dining_room_0019_out      living_room_0069a_out
# bedroom_0034_out          dining_room_0023_out      living_room_0069b_out
# bedroom_0035_out          dining_room_0024_out      living_room_0070_out
# bedroom_0036_out          dining_room_0028_out      living_room_0071_out
# bedroom_0038_out          dining_room_0029_out      living_room_0078_out
# bedroom_0039_out          dining_room_0031_out      living_room_0082_out
# bedroom_0040_out          dining_room_0033_out      living_room_0083_out
# bedroom_0041_out          dining_room_0034_out      living_room_0085_out
# bedroom_0042_out          dining_room_0037_out      living_room_0086a_out
# bedroom_0045_out          excercise_room_0001_out   living_room_0086b_out
# bedroom_0047_out          foyer_0002_out            nyu_office_0_out
# bedroom_0050_out          furniture_store_0001a_out nyu_office_1_out
# bedroom_0051_out          furniture_store_0001b_out office_0003_out
# bedroom_0052_out          furniture_store_0001c_out office_0004_out
# bedroom_0053_out          furniture_store_0001d_out office_0006_out
# bedroom_0056a_out         furniture_store_0001e_out office_0009_out
# bedroom_0056b_out         furniture_store_0001f_out office_0011_out
# bedroom_0057_out          furniture_store_0002a_out office_0012_out
# bedroom_0059_out          furniture_store_0002b_out office_0018_out
# bedroom_0060_out          furniture_store_0002c_out office_0019_out
# bedroom_0062_out          furniture_store_0002d_out office_0021_out
# bedroom_0063_out          home_office_0004_out      office_0023_out
# bedroom_0065_out          home_office_0005_out      office_0024_out
# bedroom_0066_out          home_office_0006_out      office_0025_out
# bedroom_0067a_out         home_office_0007_out      office_0026_out
# bedroom_0067b_out         home_office_0008_out      office_kitchen_0001a_out
# bedroom_0069_out          home_office_0011_out      office_kitchen_0001b_out
# bedroom_0071_out          home_office_0013_out      office_kitchen_0003_out
# bedroom_0072_out          home_storage_0001_out     playroom_0002_out
# bedroom_0074_out          indoor_balcony_0001_out   playroom_0003_out
# bedroom_0076a_out         kitchen_0003_out          playroom_0004_out
# bedroom_0078_out          kitchen_0006_out          playroom_0006_out
# bedroom_0079_out          kitchen_0008_out          printer_room_0001_out
# bedroom_0080_out          kitchen_0010_out          reception_room_0001a_out
# bedroom_0081_out          kitchen_0011a_out         reception_room_0001b_out
# bedroom_0082_out          kitchen_0011b_out         reception_room_0002_out
# bedroom_0086_out          kitchen_0016_out          reception_room_0004_out
# bedroom_0090_out          kitchen_0017_out          student_lounge_0001_out
# bedroom_0094_out          kitchen_0019a_out         study_0003_out
# bedroom_0096_out          kitchen_0019b_out         study_0004_out
# bedroom_0097_out          kitchen_0028a_out         study_0005_out
# bedroom_0098_out          kitchen_0028b_out         study_0006_out
# bedroom_0100_out          kitchen_0029a_out         study_0008_out
# bedroom_0104_out          kitchen_0029b_out         study_room_0004_out
# bedroom_0106_out          kitchen_0029c_out         study_room_0005a_out
# bedroom_0107_out          kitchen_0031_out          study_room_0005b_out
# bedroom_0113_out          kitchen_0033_out

# %%
# !ls data/nyu_data/data/nyu2_train/study_room_0004_out//
# Out:
# 1.jpg   127.jpg 155.jpg 183.jpg 210.jpg 239.jpg 267.jpg 295.jpg 46.jpg  74.jpg
# 1.png   127.png 155.png 183.png 210.png 239.png 267.png 295.png 46.png  74.png
# 10.jpg  128.jpg 156.jpg 184.jpg 211.jpg 24.jpg  268.jpg 296.jpg 47.jpg  75.jpg
# 10.png  128.png 156.png 184.png 211.png 24.png  268.png 296.png 47.png  75.png
# 100.jpg 129.jpg 157.jpg 185.jpg 212.jpg 240.jpg 269.jpg 297.jpg 48.jpg  76.jpg
# 100.png 129.png 157.png 185.png 212.png 240.png 269.png 297.png 48.png  76.png
# 101.jpg 13.jpg  158.jpg 186.jpg 213.jpg 241.jpg 27.jpg  298.jpg 49.jpg  77.jpg
# 101.png 13.png  158.png 186.png 213.png 241.png 27.png  298.png 49.png  77.png
# 102.jpg 130.jpg 159.jpg 187.jpg 214.jpg 242.jpg 270.jpg 299.jpg 5.jpg   78.jpg
# 102.png 130.png 159.png 187.png 214.png 242.png 270.png 299.png 5.png   78.png
# 103.jpg 131.jpg 16.jpg  188.jpg 215.jpg 243.jpg 271.jpg 3.jpg   50.jpg  79.jpg
# 103.png 131.png 16.png  188.png 215.png 243.png 271.png 3.png   50.png  79.png
# 104.jpg 132.jpg 160.jpg 189.jpg 216.jpg 244.jpg 272.jpg 30.jpg  51.jpg  8.jpg
# 104.png 132.png 160.png 189.png 216.png 244.png 272.png 30.png  51.png  8.png
# 105.jpg 133.jpg 161.jpg 19.jpg  217.jpg 245.jpg 273.jpg 300.jpg 52.jpg  80.jpg
# 105.png 133.png 161.png 19.png  217.png 245.png 273.png 300.png 52.png  80.png
# 106.jpg 134.jpg 162.jpg 190.jpg 218.jpg 246.jpg 274.jpg 301.jpg 53.jpg  81.jpg
# 106.png 134.png 162.png 190.png 218.png 246.png 274.png 301.png 53.png  81.png
# 107.jpg 135.jpg 163.jpg 191.jpg 219.jpg 247.jpg 275.jpg 302.jpg 54.jpg  82.jpg
# 107.png 135.png 163.png 191.png 219.png 247.png 275.png 302.png 54.png  82.png
# 108.jpg 136.jpg 164.jpg 192.jpg 22.jpg  248.jpg 276.jpg 303.jpg 55.jpg  83.jpg
# 108.png 136.png 164.png 192.png 22.png  248.png 276.png 303.png 55.png  83.png
# 109.jpg 137.jpg 165.jpg 193.jpg 220.jpg 249.jpg 277.jpg 304.jpg 56.jpg  84.jpg
# 109.png 137.png 165.png 193.png 220.png 249.png 277.png 304.png 56.png  84.png
# 11.jpg  138.jpg 166.jpg 194.jpg 221.jpg 25.jpg  278.jpg 305.jpg 57.jpg  85.jpg
# 11.png  138.png 166.png 194.png 221.png 25.png  278.png 305.png 57.png  85.png
# 110.jpg 139.jpg 167.jpg 195.jpg 222.jpg 250.jpg 279.jpg 306.jpg 58.jpg  86.jpg
# 110.png 139.png 167.png 195.png 222.png 250.png 279.png 306.png 58.png  86.png
# 111.jpg 14.jpg  168.jpg 196.jpg 223.jpg 251.jpg 28.jpg  307.jpg 59.jpg  87.jpg
# 111.png 14.png  168.png 196.png 223.png 251.png 28.png  307.png 59.png  87.png
# 112.jpg 140.jpg 169.jpg 197.jpg 224.jpg 252.jpg 280.jpg 31.jpg  6.jpg   88.jpg
# 112.png 140.png 169.png 197.png 224.png 252.png 280.png 31.png  6.png   88.png
# 113.jpg 141.jpg 17.jpg  198.jpg 225.jpg 253.jpg 281.jpg 32.jpg  60.jpg  89.jpg
# 113.png 141.png 17.png  198.png 225.png 253.png 281.png 32.png  60.png  89.png
# 114.jpg 142.jpg 170.jpg 199.jpg 226.jpg 254.jpg 282.jpg 33.jpg  61.jpg  9.jpg
# 114.png 142.png 170.png 199.png 226.png 254.png 282.png 33.png  61.png  9.png
# 115.jpg 143.jpg 171.jpg 2.jpg   227.jpg 255.jpg 283.jpg 34.jpg  62.jpg  90.jpg
# 115.png 143.png 171.png 2.png   227.png 255.png 283.png 34.png  62.png  90.png
# 116.jpg 144.jpg 172.jpg 20.jpg  228.jpg 256.jpg 284.jpg 35.jpg  63.jpg  91.jpg
# 116.png 144.png 172.png 20.png  228.png 256.png 284.png 35.png  63.png  91.png
# 117.jpg 145.jpg 173.jpg 200.jpg 229.jpg 257.jpg 285.jpg 36.jpg  64.jpg  92.jpg
# 117.png 145.png 173.png 200.png 229.png 257.png 285.png 36.png  64.png  92.png
# 118.jpg 146.jpg 174.jpg 201.jpg 23.jpg  258.jpg 286.jpg 37.jpg  65.jpg  93.jpg
# 118.png 146.png 174.png 201.png 23.png  258.png 286.png 37.png  65.png  93.png
# 119.jpg 147.jpg 175.jpg 202.jpg 230.jpg 259.jpg 287.jpg 38.jpg  66.jpg  94.jpg
# 119.png 147.png 175.png 202.png 230.png 259.png 287.png 38.png  66.png  94.png
# 12.jpg  148.jpg 176.jpg 203.jpg 231.jpg 26.jpg  288.jpg 39.jpg  67.jpg  95.jpg
# 12.png  148.png 176.png 203.png 231.png 26.png  288.png 39.png  67.png  95.png
# 120.jpg 149.jpg 177.jpg 204.jpg 232.jpg 260.jpg 289.jpg 4.jpg   68.jpg  96.jpg
# 120.png 149.png 177.png 204.png 232.png 260.png 289.png 4.png   68.png  96.png
# 121.jpg 15.jpg  178.jpg 205.jpg 233.jpg 261.jpg 29.jpg  40.jpg  69.jpg  97.jpg
# 121.png 15.png  178.png 205.png 233.png 261.png 29.png  40.png  69.png  97.png
# 122.jpg 150.jpg 179.jpg 206.jpg 234.jpg 262.jpg 290.jpg 41.jpg  7.jpg   98.jpg
# 122.png 150.png 179.png 206.png 234.png 262.png 290.png 41.png  7.png   98.png
# 123.jpg 151.jpg 18.jpg  207.jpg 235.jpg 263.jpg 291.jpg 42.jpg  70.jpg  99.jpg
# 123.png 151.png 18.png  207.png 235.png 263.png 291.png 42.png  70.png  99.png
# 124.jpg 152.jpg 180.jpg 208.jpg 236.jpg 264.jpg 292.jpg 43.jpg  71.jpg
# 124.png 152.png 180.png 208.png 236.png 264.png 292.png 43.png  71.png
# 125.jpg 153.jpg 181.jpg 209.jpg 237.jpg 265.jpg 293.jpg 44.jpg  72.jpg
# 125.png 153.png 181.png 209.png 237.png 265.png 293.png 44.png  72.png
# 126.jpg 154.jpg 182.jpg 21.jpg  238.jpg 266.jpg 294.jpg 45.jpg  73.jpg
# 126.png 154.png 182.png 21.png  238.png 266.png 294.png 45.png  73.png

# %% [markdown]
# The format seems to consist of one (RGB?) color image + one depth mask (D, one channel) per item. Let's import an image lib and have a look. The training folder contains subdirectories whereas the test folder contains the images directly.

# %%
from PIL import Image
from pathlib import Path
import numpy as np

data_path = Path("./data/nyu_data/data")
test_path = data_path / "nyu2_test"
sample_num = "01155"
test_sample_colors = Image.open(test_path / (sample_num + "_colors.png"))
test_sample_depth = Image.open(test_path / (sample_num + "_depth.png"))

# %%
print(test_sample_colors.size)
test_sample_colors
# Out:
# (640, 480)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x480>

# %%
print(test_sample_depth.size)
test_sample_depth
# Out:
# (640, 480)
# <PIL.PngImagePlugin.PngImageFile image mode=I size=640x480>

# %%
test_sample_depth.mode, test_sample_depth.getbands()
# Out:
# ('I', ('I',))

# %%
depth_channel = np.array(test_sample_depth)
depth_channel
# Out:
# array([[2466, 2466, 2466, ..., 1224, 1224, 1224],
#        [2466, 2466, 2466, ..., 1224, 1224, 1223],
#        [2466, 2466, 2466, ..., 1224, 1223, 1223],
#        ...,
#        [1956, 1956, 1956, ..., 1001, 1001, 1001],
#        [1956, 1956, 1956, ..., 1001, 1001, 1001],
#        [1956, 1956, 1955, ..., 1001, 1001, 1001]], dtype=int32)

# %%
depth_channel.shape
# Out:
# (480, 640)

# %% [markdown]
# ### 🤗 approach

# %% [markdown]
# I was interested in the state-of-the-art (SOTA), so I quickly googled and landed on [paperswithcode](https://paperswithcode.com/dataset/nyuv2). There I found the HuggingFace version of the dataset which will probably save time.

# %%
from datasets import load_dataset
import numpy as np
import matplotlib.pyplot as plt

# %%
cmap = plt.cm.viridis

ds = load_dataset("sayakpaul/nyu_depth_v2")
# Out:
# Downloading data:   0%|          | 0.00/3.00G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.00G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.00G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.00G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.00G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.00G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.00G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.00G [00:00<?, ?B/s]

# %%
def colored_depthmap(depth, d_min=None, d_max=None):
    if d_min is None:
        d_min = np.min(depth)
    if d_max is None:
        d_max = np.max(depth)
    depth_relative = (depth - d_min) / (d_max - d_min)
    return 255 * cmap(depth_relative)[:,:,:3] # H, W, C


def merge_into_row(input, depth_target):
    input = np.array(input)
    depth_target = np.squeeze(np.array(depth_target))

    d_min = np.min(depth_target)
    d_max = np.max(depth_target)
    depth_target_col = colored_depthmap(depth_target, d_min, d_max)
    img_merge = np.hstack([input, depth_target_col])
    
    return img_merge


random_indices = np.random.choice(len(ds["train"]), 9).tolist()
train_set = ds["train"]

plt.figure(figsize=(15, 6))

for i, idx in enumerate(random_indices):
    ax = plt.subplot(3, 3, i + 1)
    image_viz = merge_into_row(
        train_set[idx]["image"], train_set[idx]["depth_map"]
    )
    plt.imshow(image_viz.astype("uint8"))
    plt.axis("off")

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu')
